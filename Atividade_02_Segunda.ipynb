# %% [markdown]
# <a href="https://colab.research.google.com/github/janielcarneiro/Atividade_Avanti_02/blob/master/Atividade_02_Segunda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#FILTRO DA MÉDIA
#Carregando filtro da Média
import cv2
from matplotlib import pyplot as plt

#Carregar a imagem
caminho_imagem = '/content/drive/MyDrive/Atividade_Atlantico_2/Cidade-da-gente.jpg'
imagem = cv2.imread(caminho_imagem)

#APLICAR O FILTRO DE MÉDIA

#tamanho da janela da media
blurred_image = cv2.blur(imagem, (5,5))

#plotar a imagem Media suavizada
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.title('Colorida')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Imagem Suavizada(Filtro Média)')
# Out:
# Text(0.5, 1.0, 'Imagem Suavizada(Filtro Média)')

# %%
#FILTRO DA GAUSSIANO

#Carregando filtro da Média
import cv2
from matplotlib import pyplot as plt

#Carregar a imagem
caminho_imagem = '/content/drive/MyDrive/Atividade_Atlantico_2/Cidade-da-gente.jpg'
imagem = cv2.imread(caminho_imagem)

#APLICAR FILTRO GAUSSIANO

#tamanho da janela da media
blurred_image = cv2.GaussianBlur(imagem, (7,7), 0)

#plotar a imagem Media suavizada
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.title('Colorida')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Imagem Suavizada(Filtro Gaussiano)')
# Out:
# Text(0.5, 1.0, 'Imagem Suavizada(Filtro Gaussiano)')

# %%
#Carregando filtro da Médiana
import cv2
from matplotlib import pyplot as plt

#Carregar a imagem
caminho_imagem = '/content/drive/MyDrive/Atividade_Atlantico_2/Cidade-da-gente.jpg'
imagem = cv2.imread(caminho_imagem)

#APLICAR FILTRO MÉDIANA

#tamanho da janela da media
blurred_image = cv2.medianBlur(imagem, 5)

#plotar a imagem Media suavizada
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.title('Colorida')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Imagem Suavizada(Filtro Médiana)')
# Out:
# Text(0.5, 1.0, 'Imagem Suavizada(Filtro Médiana)')
